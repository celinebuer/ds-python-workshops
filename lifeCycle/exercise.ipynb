# %%
import matplotlib # for importing image/plotting/etc
import matplotlib.pyplot as plt # we are going to use abbreviation 
from matplotlib import image as img # for image importing
import pandas as pd # for data import/data wrangling
import seaborn as sns # for statistical visualization
import statsmodels.api as sm # for statistical models
from statsmodels.formula.api import ols

# %%
iris = pd.read_csv('IRIS.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.species.value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# filtering only the versicolor species
iris_filtered = iris[iris['species'] == 'Iris-versicolor']

# %%
iris_filtered.species.unique()
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
plt.scatter(iris_filtered['petal_length'], iris_filtered['petal_width'])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title("Versicolor")
# Out:
# Text(0.5, 1.0, 'Versicolor')

# %%
plt.scatter(iris['sepal_length'], iris['species'])
plt.xlabel('Sepal Length')
plt.ylabel('Species')
# Out:
# Text(0, 0.5, 'Species')

# %%
sns.boxplot(data = iris, x = 'species' , y = 'sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(data = iris, x = 'species', y = 'petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
# try doing some linear regression on the petal width and petal length

model_iris = ols('petal_width ~ petal_length', data = iris).fit()

# %%
print(model_iris.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            petal_width   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     1877.
# Date:                Wed, 05 Feb 2025   Prob (F-statistic):           5.78e-86
# Time:                        16:57:05   Log-Likelihood:                 24.400
# No. Observations:                 150   AIC:                            -44.80
# Df Residuals:                     148   BIC:                            -38.78
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.3665      0.040     -9.188      0.000      -0.445      -0.288
# ...
